# %% [markdown]
# <a href="https://colab.research.google.com/gist/BurhanYerebakan/4bd73fda552cf3d3b5b558a040afa389/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages("ggplot2::")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘ggplot2::’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
library(ggplot2)
library(dplyr)
midwest
# Out:
#     PID  county      state area  poptotal popdensity popwhite popblack
# 1   561  ADAMS       IL    0.052   66090   1270.9615   63917     1702
# 2   562  ALEXANDER   IL    0.014   10626    759.0000    7054     3496
# 3   563  BOND        IL    0.022   14991    681.4091   14477      429
# 4   564  BOONE       IL    0.017   30806   1812.1176   29344      127
# 5   565  BROWN       IL    0.018    5836    324.2222    5264      547
# 6   566  BUREAU      IL    0.050   35688    713.7600   35157       50
# 7   567  CALHOUN     IL    0.017    5322    313.0588    5298        1
# 8   568  CARROLL     IL    0.027   16805    622.4074   16519      111
# 9   569  CASS        IL    0.024   13437    559.8750   13384       16
# 10  570  CHAMPAIGN   IL    0.058  173025   2983.1897  146506    16559
# 11  571  CHRISTIAN   IL    0.042   34418    819.4762   34176       82
# 12  572  CLARK       IL    0.030   15921    530.7000   15842       10
# ...

# %%
names(midwest)
# Out:
#  [1] "PID"                  "county"               "state"
#  [4] "area"                 "poptotal"             "popdensity"
#  [7] "popwhite"             "popblack"             "popamerindian"
# [10] "popasian"             "popother"             "percwhite"
# [13] "percblack"            "percamerindan"        "percasian"
# [16] "percother"            "popadults"            "perchsd"
# [19] "percollege"           "percprof"             "poppovertyknown"
# [22] "percpovertyknown"     "percbelowpoverty"     "percchildbelowpovert"
# [25] "percadultpoverty"     "percelderlypoverty"   "inmetro"
# [28] "category"

# %%
options(scipen = 9999)
ggplot(midwest, aes(area, poptotal)) + geom_point() + geom_smooth(method = "loess")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggplot(midwest, aes(area, poptotal)) + geom_point() + xlim(0, .06) + ylim(0,1000000) + labs(title = "is this Population growing too much?", 
subtitle = "From the Midwest Dataset", x = "Area", y = "Population", caption = "Source:Midwest")
# Out:
# Warning message:
# “Removed 27 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(midwest, aes(area, poptotal)) + geom_point() + ggtitle("Is the Pop") + xlab("") + ylab("")
# Out:
# plot without title

# %%
library(scales)
ggplot(midwest, aes(x = area, y = poptotal)) + geom_point(aes(col = state)) + xlim(0, .06) + ylim(0,1000000) + labs(title = "is this Population growing too much?", 
subtitle = "From the Midwest Dataset", x = "Area", y = "Population", caption = "Source:Midwest") + scale_x_continuous(breaks = seq(0, .12, .02), 
labels = percent) + theme_bw()
# Out:
# Scale for 'x' is already present. Adding another scale for 'x', which will
# replace the existing scale.
#
# Warning message:
# “Removed 4 rows containing missing values (geom_point).”
# plot without title
